# %%
# !pip install opencv-python
# !pip install scikit-image
# !pip install warp-lang
# !pip install warp-py
# Out:
# Requirement already satisfied: opencv-python in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opencv-python) (1.26.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: scikit-image in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=10.1 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (11.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (2025.3.13)
# Requirement already satisfied: packaging>=21 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (0.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: warp-lang in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.6.2)
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from warp-lang) (1.26.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting warp-py
#   Downloading warp_py-0.1.4-py3-none-any.whl.metadata (3.1 kB)
# Collecting iterfzf==0.5.0.20.0 (from warp-py)
#   Downloading iterfzf-0.5.0.20.0-py2.py3-none-manylinux1_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from iterfzf==0.5.0.20.0->warp-py) (75.6.0)
# Downloading warp_py-0.1.4-py3-none-any.whl (6.7 kB)
# Downloading iterfzf-0.5.0.20.0-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.6 MB/s eta 0:00:00eta 0:00:01
# Installing collected packages: iterfzf, warp-py
# Successfully installed iterfzf-0.5.0.20.0 warp-py-0.1.4
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# Library yang sering digunakan
import os, shutil
import zipfile
import random
from random import sample
import shutil
from shutil import copyfile
import pathlib
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm as tq
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Libraries untuk pemrosesan data gambar
import cv2
from PIL import Image
import skimage
from skimage import io
from skimage.transform import resize
from skimage.transform import rotate, AffineTransform, warp
from skimage import img_as_ubyte
from skimage.exposure import adjust_gamma
from skimage.util import random_noise

# %%
# Libraries untuk pembangunan model
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.layers import InputLayer, Conv2D, SeparableConv2D, MaxPooling2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
# Out:
# 2025-03-17 03:44:23.057979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742183063.189651   23280 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742183063.223589   23280 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742183063.487939   23280 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742183063.487980   23280 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742183063.487986   23280 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742183063.487990   23280 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-17 03:44:23.510507: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Mencetak versi TensorFlow yang sedang digunakan
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# ## Data Loading

# %%
# Download kaggle dataset and unzip the file
# !kaggle datasets download -d tolgadincer/labeled-chest-xray-images
# !unzip labeled-chest-xray-images.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tolgadincer/labeled-chest-xray-images
# License(s): other
# Archive:  labeled-chest-xray-images.zip
#   inflating: chest_xray/test/NORMAL/NORMAL-1049278-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1110860-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-11419-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-115218-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1160949-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1212407-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1228182-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1283091-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1318320-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1368583-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1430636-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1520670-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-152130-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-159472-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1608079-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1627110-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1698651-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-171327-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1759114-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1763721-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1768815-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1771524-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1784004-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1803887-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1858497-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-186900-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1931427-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-1944537-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2107985-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2123652-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2162145-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-217318-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2233350-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2256620-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2274324-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2280080-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2298727-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2403676-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2477476-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2514572-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2578531-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2704875-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2728578-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2771774-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2798826-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-283245-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-284601-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2850034-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2862975-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2870844-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2924895-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-2959018-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3065672-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3098476-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3117193-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3170711-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3189250-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3267425-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3293997-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3322209-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3346259-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3395085-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3396581-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3397442-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3437568-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3459196-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3464500-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3464500-0002.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3464500-0003.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3487620-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3518268-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3549035-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3564811-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3624496-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3686746-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3733696-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3782395-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3837280-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3921425-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3937418-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3983280-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-3985743-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4172448-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4190414-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4196521-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4315572-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4340661-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4363211-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4511610-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4512-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4513268-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4534031-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4675782-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-472699-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4766279-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4834475-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4852815-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4886177-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4906464-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4911367-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4921478-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-4955194-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5083836-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5148117-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5175014-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5180957-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5200363-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-520267-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-522391-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-528189-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5349917-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5356114-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5388550-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5401638-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5402107-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-541071-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5423277-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5425295-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5459424-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5472638-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5487025-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5498455-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5511958-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5513974-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5538803-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5545906-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5578360-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5601980-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5611875-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-561684-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5661793-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5661793-0002.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5714306-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5789014-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5889760-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5893138-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-5997885-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6000527-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6085151-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6106856-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6112608-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6137647-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6190523-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6195450-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6204576-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6267994-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6293151-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6297597-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-630880-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6322108-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6332708-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6332708-0002.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6332708-0003.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6342197-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6395296-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6410283-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6442221-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6497443-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6503977-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6518197-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6524124-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6544436-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6569259-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6650392-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6667079-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-667173-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6703189-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6713743-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6874528-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-6983998-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7031638-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-706052-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7082548-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-71002-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7100645-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7165123-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7225301-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7236364-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-724740-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7331861-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7398200-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7423096-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-745902-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7483489-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7488601-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7519498-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-754920-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7590045-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7695736-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7738170-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7804528-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-78265-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-786023-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7922918-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7950798-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-7961936-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8014191-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8207090-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8278998-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8305321-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8305499-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8406720-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8417023-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8418332-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8441235-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8448068-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8495317-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-857568-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8586608-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8661138-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8698006-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-870639-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8750803-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8836138-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8876914-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8907762-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-8944072-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9054075-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9077486-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9092354-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9104493-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9145111-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9194822-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9217241-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9260113-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9275512-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9334007-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9343440-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9441169-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9708691-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9717513-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-976006-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9799657-0001.jpeg
#   inflating: chest_xray/test/NORMAL/NORMAL-9896495-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1135262-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1135262-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1135262-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1135262-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1220485-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1351146-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1514320-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1514320-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1514320-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1602272-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1602272-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1602272-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1602272-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1714895-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1714895-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1714895-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-1768914-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2034017-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2131702-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2131702-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2131702-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-227418-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-227418-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-227418-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-227418-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2429208-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2429208-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2429208-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2772694-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-2772694-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3060399-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3060399-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3060399-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3060399-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3105669-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3105669-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3105669-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3105669-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3105669-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3127602-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3127602-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3436159-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3436159-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3436159-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3865791-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3865791-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3865791-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3865791-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3865791-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3961172-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3961172-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3961172-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-3961172-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4006043-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4006043-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4006043-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4059589-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4059589-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4059589-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4059589-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-40699-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-40699-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4070745-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4130801-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4130801-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4130801-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4161430-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4161430-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4161430-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4167818-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4167818-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4167818-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0007.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0008.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4269599-0009.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4322734-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4322734-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4345731-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4345731-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4345731-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4345731-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-4376803-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5141192-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5141192-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5141192-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5155977-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5155977-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5155977-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5155977-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5155977-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-518323-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-518323-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-518323-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5240350-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5240350-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5240350-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5240350-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5421131-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5421131-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5451280-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5451280-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-545831-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5489623-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5489623-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5489623-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0007.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5660566-0008.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5754167-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5754167-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-5757955-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6105615-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6105615-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6168941-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6168941-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6402155-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6402155-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6402155-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6402155-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6523466-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6523466-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6806075-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6806075-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6806075-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6806075-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6806075-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6833685-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6833685-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6833685-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6950003-0007.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-6987875-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7051071-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7051071-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7098043-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7136666-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7257218-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7257218-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7257218-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7257218-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7257218-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7346761-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7720431-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7720431-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7720431-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-7720431-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8046863-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8046863-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8190872-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8190872-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8190872-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8190872-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8190872-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-821920-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-821920-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8285922-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8285922-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8285922-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8285922-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8285922-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-840611-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-840611-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-840611-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-840611-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-840611-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-846757-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-846757-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8563288-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8837254-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8846908-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8846908-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8846908-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8983865-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8983865-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8983865-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8983865-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-8983865-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9050379-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9060950-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9060950-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9156003-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9156003-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9156003-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9156003-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9156003-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9182718-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9242636-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-932292-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-932292-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-932292-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9364007-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9364007-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9364007-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-949117-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9503383-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9673743-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9673743-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9673743-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9764136-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9857270-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9857270-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9857270-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9857270-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9913238-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9913238-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/BACTERIA-9913238-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1056329-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1142234-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1207991-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-131422-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0004.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0005.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0006.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1352878-0007.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1423083-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1463523-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1517175-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1540910-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1540910-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-1795675-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2040583-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2040583-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2061674-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2102459-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2344316-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2352342-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2352342-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2470676-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-258000-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-262135-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-280992-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2831144-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-2914571-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3008952-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-30184-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3028666-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3039338-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3119878-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3174339-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3225323-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3239718-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3239718-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3426682-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3439481-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3522052-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3565661-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3635859-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3698459-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3746644-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3768496-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3814177-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3828598-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3828598-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3835085-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3835085-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3838349-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3906469-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-3915569-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4009702-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4033321-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4190128-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4275213-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4276353-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-432590-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4355102-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4360206-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4405644-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-447130-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4533169-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4655012-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4664910-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4810299-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4810299-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-48197-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4840553-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4852350-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-490019-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-490019-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-4911614-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5069337-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5180281-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5271295-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5366974-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5391810-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5508710-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5660566-0009.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5708148-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5708148-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5741681-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5813112-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5864551-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5880719-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-5927483-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6076183-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6076183-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6079770-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6138035-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6207158-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6249454-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6249454-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6249454-0003.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6682185-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6733553-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6812602-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6828836-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6831597-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6840343-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6844248-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-6844248-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7014527-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7014527-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7318158-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7337079-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7385225-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7441806-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7441806-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7477247-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7589381-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7638941-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7688430-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7788460-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7822291-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7909775-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-7979-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8106836-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-820420-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8314555-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8377377-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8385372-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-842024-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8427429-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8435135-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8507816-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8544560-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8574414-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-874167-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-8903181-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9018258-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9039335-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-904779-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9240664-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9325276-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9342284-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9476607-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9564688-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9564688-0002.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9584831-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9671740-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9783315-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9890836-0001.jpeg
#   inflating: chest_xray/test/PNEUMONIA/VIRUS-9968655-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1003233-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1012843-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1014768-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1023731-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1029510-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1031320-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1034239-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1041364-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1044645-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1055663-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1063934-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1064313-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1064313-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1068231-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1068326-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1070073-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1070073-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1080088-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1097039-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1101909-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1128157-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1140710-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1150393-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1156778-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1165014-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1165014-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1170804-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1177627-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1196989-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1203236-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1206638-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1241506-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1243491-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1261648-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1311502-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1314288-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1317636-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-132181-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1323979-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1325139-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-133685-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1352927-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1355454-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-137300-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-141619-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1429145-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1429145-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1440428-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1444388-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1444388-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-145240-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1455093-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1456124-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1456124-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1457994-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1465577-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1476994-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1482788-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1504793-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1505602-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1505602-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1507671-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1507671-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1507671-0003.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1513368-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1522956-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1528760-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1530010-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1530010-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1533758-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-155211-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1556834-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1557045-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1558430-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1563073-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1566405-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1566442-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1576353-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1576353-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1589680-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-159556-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1602427-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1602738-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1602738-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1619233-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1696866-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1697483-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1699306-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1701841-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1702319-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1702319-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-170867-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-170867-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1715076-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1739213-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1756042-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1769145-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-177055-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-177055-0002.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1770564-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-179015-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1798503-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1830070-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1833676-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-183773-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1842649-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1843288-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1860692-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1862776-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1866844-0001.jpeg
#   inflating: chest_xray/train/NORMAL/NORMAL-1870906-0001.jpeg
# ...
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8310504-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8313249-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8324394-0010.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8341352-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8343272-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8346601-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8351811-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8352680-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8352680-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8360857-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8365091-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8369417-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8375877-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8403601-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8423652-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8426593-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-843473-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-843966-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8446214-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8446523-0009.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8451938-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8462046-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8475797-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8478954-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8481308-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8485124-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8488185-0005.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8498464-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8498536-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8512880-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8525654-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8527391-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-853038-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-853038-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8550080-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8550444-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8550709-0009.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8550709-0010.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8550709-0011.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8562352-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8572102-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-857613-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-857613-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-857613-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8589814-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8590556-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8597098-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8600331-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8607121-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8608254-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8614051-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-864208-0005.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8645887-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8659640-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8659640-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8660561-0012.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8666617-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-866933-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8679052-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8688218-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8688218-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8690813-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-86966-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-869984-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8705009-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-871322-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8716601-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8716601-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8716601-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8718799-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8720773-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-873293-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-873293-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8738712-0012.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8739469-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8748267-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8750763-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8775213-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8797622-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8806791-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8814390-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8833130-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8841513-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8841513-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8845554-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8849094-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-886684-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8871315-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8888277-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8917885-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8939025-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8939376-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8941083-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-894333-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8967096-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8982418-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8995112-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8995871-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-8995871-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9026424-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9028120-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9028120-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9028120-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9033903-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9035476-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9039351-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9044474-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9044719-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9046262-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9084290-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9084290-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9088808-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9115368-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9123837-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9127353-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9130179-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9130179-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9130179-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9156894-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9162717-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9175020-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9176009-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9176369-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9188112-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9197445-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9208098-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-92115-0005.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-923246-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9237186-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9243857-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9248466-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9250380-0006.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9257521-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9269035-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-927060-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9286241-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9289090-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9291784-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9310133-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9332973-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9332973-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9345113-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-935458-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361672-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0005.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0006.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0008.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9361906-0009.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9363974-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9364407-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9365328-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9372391-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9377680-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-939876-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9400981-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-940302-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9412679-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9434229-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9438146-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9451950-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9464756-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9480095-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9481072-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9487238-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9496210-0005.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9496210-0006.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9497066-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9514863-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9515846-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9527033-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9539563-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9539609-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9543809-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9550884-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9551241-0006.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9559998-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9561808-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9561808-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-957582-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9582372-0009.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9594118-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9597998-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-960851-0006.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9613278-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9613278-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9613951-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9624185-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9624424-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9624424-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9629926-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9629926-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9633130-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9650028-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9650164-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9662232-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-966858-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9674936-0007.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9674936-0008.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9677398-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9679656-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9682067-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9694192-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9694192-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9722112-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9723601-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9727802-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9727803-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9727803-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9730180-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9737718-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9742081-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9801714-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9805697-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9814452-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9815549-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9822795-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9827460-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9829865-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9839787-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9844887-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9867917-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-987036-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-987036-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9887625-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9887625-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9902199-0004.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-990412-0008.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-990412-0009.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-990515-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9916753-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9922025-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9922492-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9934736-0003.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9947411-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9962961-0002.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9963654-0001.jpeg
#   inflating: chest_xray/train/PNEUMONIA/VIRUS-9975428-0002.jpeg

# %% [markdown]
# ## Data Preparation

# %%
import os
import shutil

# %%
# Direktori awal untuk train dan test
train_dir = "chest_xray/train"
test_dir = "chest_xray/test"
 
# Direktori baru untuk dataset gabungan
combined_dir = "chest_xray/dataset"

# %%
# Buat direktori baru untuk dataset gabungan
os.makedirs(combined_dir, exist_ok=True)

# %%
# Salin file dan folder dari train
for category in os.listdir(train_dir):
    category_dir = os.path.join(train_dir, category)
    if os.path.isdir(category_dir):
        shutil.copytree(category_dir, os.path.join(combined_dir, category), dirs_exist_ok=True)
 
# Salin file dan folder dari test
for category in os.listdir(test_dir):
    category_dir = os.path.join(test_dir, category)
    if os.path.isdir(category_dir):
        shutil.copytree(category_dir, os.path.join(combined_dir, category), dirs_exist_ok=True)

# %% [markdown]
# ## Dataset Checking

# %%
# Membuat kamus yang menyimpan gambar untuk setiap kelas dalam data
lung_image = {}
 
# Tentukan path sumber train
path = "chest_xray/"
path_sub = os.path.join(path, "dataset")
for i in os.listdir(path_sub):
    lung_image[i] = os.listdir(os.path.join(path_sub, i))
 
# Menampilkan secara acak 5 gambar di bawah setiap dari 2 kelas dari data.
# Anda akan melihat gambar yang berbeda setiap kali kode ini dijalankan.
path_sub = "chest_xray/dataset/"
 
# Menampilkan secara acak 5 gambar di bawah setiap kelas dari data latih
fig, axs = plt.subplots(len(lung_image.keys()), 5, figsize=(15, 15))
 
for i, class_name in enumerate(os.listdir(path_sub)):
    images = np.random.choice(lung_image[class_name], 5, replace=False)
 
    for j, image_name in enumerate(images):
        img_path = os.path.join(path_sub, class_name, image_name)
        img = Image.open(img_path).convert("L")  # Konversi menjadi skala keabuan
        axs[i, j].imshow(img, cmap='gray')
        axs[i, j].set(xlabel=class_name, xticks=[], yticks=[])
 
 
fig.tight_layout()

# %%
# Definisikan path sumber
lung_path = "chest_xray/dataset/"
 
# Buat daftar yang menyimpan data untuk setiap nama file, path file, dan label dalam data
file_name = []
labels = []
full_path = []
 
# Dapatkan nama file gambar, path file, dan label satu per satu dengan looping, dan simpan sebagai dataframe
for path, subdirs, files in os.walk(lung_path):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)
 
distribution_train = pd.DataFrame({"path":full_path, 'file_name':file_name, "labels":labels})
 
# Plot distribusi gambar di setiap kelas
Label = distribution_train['labels']
plt.figure(figsize = (6,6))
sns.set_style("darkgrid")
plot_data = sns.countplot(Label)

# %% [markdown]
# Terlihat bahwa penyebaran data tidak merata antara kedua label. Label pneumonia memiliki jumlah yang lebih banyak dibandingkan dengan label normal. Kondisi ini dapat menyebabkan **ketidakseimbangan pada pembelajaran model**, yaitu model mungkin cenderung lebih baik dalam memprediksi kelas mayoritas daripada kelas minoritas.
#
# Untuk mengatasi hal ini, tahapan data augmentation diperlukan. Kita akan menghasilkan variasi dari data yang ada untuk kelas minoritas agar jumlahnya setara dengan kelas mayoritas. Ini akan membantu model untuk belajar dengan lebih baik dan menghasilkan prediksi yang lebih seimbang.

# %% [markdown]
# ## Data Augmentation

# %%
# Membuat fungsi untuk melakukan rotasi berlawanan arah jarum jam
def anticlockwise_rotation(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    sudut = random.randint(0,180)
    return rotate(img, sudut)
 
# Membuat fungsi untuk melakukan rotasi searah jarum jam
def clockwise_rotation(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    sudut = random.randint(0,180)
    return rotate(img, -sudut)
 
# Membuat fungsi untuk membalik gambar secara vertikal dari atas ke bawah
def flip_up_down(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    return np.flipud(img)
 
# Membuat fungsi untuk memberikan efek peningkatan kecerahan pada gambar
def add_brightness(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    img = adjust_gamma(img, gamma=0.5,gain=1)
    return img
 
# Membuat fungsi untuk memberikan efek blur pada gambar
def blur_image(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    return cv2.GaussianBlur(img, (9,9),0)
 
# Membuat fungsi untuk memberikan efek pergeseran acak pada gambar
def sheared(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    transform = AffineTransform(shear=0.2)
    shear_image = warp(img, transform, mode="wrap")
    return shear_image
 
# Membuat fungsi untuk melakukan pergeseran melengkung pada gambar
def warp_shift(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    transform = AffineTransform(translation=(0,40))
    warp_image = warp(img, transform, mode="wrap")
    return warp_image

# %%
# Membuat variabel transformasi yang akan menyimpan semua proses pra-pemrosesan yang telah dilakukan sebelumnya
transformations = { 'rotate anticlockwise': anticlockwise_rotation,
                    'rotate clockwise': clockwise_rotation,
                    'warp shift': warp_shift,
                    'blurring image': blur_image,
                    'add brightness' : add_brightness,
                    'flip up down': flip_up_down,
                    'shear image': sheared
                  }
 
images_path="chest_xray/dataset/NORMAL" # Path untuk gambar asli
augmented_path="chest_xray/dataset/NORMAL_augmented" # Path untuk gambar yang sudah diaugmentasi
images=[] # Penyimpanan gambar yang telah melalui pra-pemrosesan
 
# Baca nama gambar dari folder dan tambahkan path ke dalam array "images"
for im in os.listdir(images_path):
    images.append(os.path.join(images_path,im))
 
# Jumlah gambar yang akan ditambahkan dengan hasil transformasi augmentasi, jumlahnya disesuaikan sesuai kebutuhan
# Variabel untuk melakukan iterasi sampai jumlah gambar yang ditentukan dalam images_to_generate
images_to_generate=2000
i=1
 
while i<=images_to_generate:
    image=random.choice(images)
    try:
        original_image = io.imread(image)
        transformed_image=None
        n = 0      # Variabel untuk melakukan iterasi sampai jumlah transformasi yang akan diterapkan
        transformation_count = random.randint(1, len(transformations)) # Pilih jumlah transformasi acak yang akan diterapkan pada gambar
 
        while n <= transformation_count:
            key = random.choice(list(transformations)) # Secara acak memilih dan memanggil metode
            transformed_image = transformations[key](original_image)
            n = n + 1
 
        new_image_path= "%s/augmented_image_%s.jpg" %(images_path, i)
        transformed_image = img_as_ubyte(transformed_image)  # Mengonversi gambar ke format byte yang tidak ditandatangani, dengan nilai dalam [0, 255]
        cv2.imwrite(new_image_path, transformed_image)  # Simpan hasil transformasi augmentasi pada gambar ke path yang ditentukan
        i =i+1
    except ValueError as e:
        print('could not read the',image ,':',e,'hence skipping it.')

# %%
# Definisikan path sumber
lung_path = "chest_xray/dataset/"
 
# Buat daftar yang menyimpan data untuk setiap nama file, path file, dan label dalam data
file_name = []
labels = []
full_path = []
 
# Dapatkan nama file gambar, path file, dan label satu per satu dengan looping, dan simpan sebagai dataframe
for path, subdirs, files in os.walk(lung_path):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)
 
distribution_train = pd.DataFrame({"path":full_path, 'file_name':file_name, "labels":labels})
 
# Plot distribusi gambar di setiap kelas
Label = distribution_train['labels']
plt.figure(figsize = (6,6))
sns.set_style("darkgrid")
plot_data = sns.countplot(Label)

# %% [markdown]
# ## Data Splitting

# %%
mypath = 'chest_xray/dataset/'

file_name = []
labels = []
full_path = []

for path, subdirs, files in os.walk(mypath):
    if path.split('/')[-1] != "NORMAL_AUGMENTED":  # Kecualikan folder NORMAL_AUGMENTED
        for name in files:
            full_path.append(os.path.join(path, name))
            labels.append(path.split('/')[-1])  # Simpan nama folder sebagai label
            file_name.append(name)

# Memasukkan variabel ke DataFrame agar lebih rapi
df = pd.DataFrame({"path": full_path, "file_name": file_name, "labels": labels})

# Melihat jumlah data gambar pada masing-masing label
print(df.groupby(['labels']).size())
# Out:
# labels
# NORMAL       3583
# PNEUMONIA    4273
# dtype: int64

# %%
# Variabel yang digunakan pada pemisahan data ini di mana variabel x = data path dan y = data labels
 
X= df['path']
y= df['labels']

# Split dataset awal menjadi data train dan test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=300)

# %%
# Menyatukan ke dalam masing-masing dataframe
df_train = pd.DataFrame({'path':X_train,'labels':y_train,'set':'train'})
df_test = pd.DataFrame({'path':X_test,'labels':y_test,'set':'test'})

# %%
# Gabungkan DataFrame df_tr dan df_te
df_all = pd.concat([df_train, df_test], ignore_index=True)
 
print('===================================================== \n')
print(df_all.groupby(['set', 'labels']).size(), '\n')
print('===================================================== \n')
 
# Cek sampel data
print(df_all.sample(5))
 
# Memanggil dataset asli yang berisi keseluruhan data gambar yang sesuai dengan labelnya
datasource_path = "chest_xray/dataset/"
# Membuat variabel Dataset, tempat menampung data yang telah dilakukan pembagian data training dan testing
dataset_path = "Dataset-Final/"
# Out:
# =====================================================
#
# set    labels
# test   NORMAL        733
#        PNEUMONIA     839
# train  NORMAL       2850
#        PNEUMONIA    3434
# dtype: int64
#
# =====================================================
#
#                                                    path     labels    set
# 5388  chest_xray/dataset/NORMAL/NORMAL-7605819-0001....     NORMAL  train
# 4416  chest_xray/dataset/PNEUMONIA/VIRUS-2365050-000...  PNEUMONIA  train
# 6271  chest_xray/dataset/PNEUMONIA/VIRUS-1355733-000...  PNEUMONIA  train
# 1915  chest_xray/dataset/NORMAL/augmented_image_1742...     NORMAL  train
# 6854  chest_xray/dataset/NORMAL/augmented_image_148.jpg     NORMAL   test

# %%
for index, row in tq(df_all.iterrows()):
    # Deteksi filepath
    file_path = row['path']
    if os.path.exists(file_path) == False:
            file_path = os.path.join(datasource_path,row['labels'],row['image'].split('.')[0])
 
    # Buat direktori tujuan folder
    if os.path.exists(os.path.join(dataset_path,row['set'],row['labels'])) == False:
        os.makedirs(os.path.join(dataset_path,row['set'],row['labels']))
 
    # Tentukan tujuan file
    destination_file_name = file_path.split('/')[-1]
    file_dest = os.path.join(dataset_path,row['set'],row['labels'],destination_file_name)
 
    # Salin file dari sumber ke tujuan
    if os.path.exists(file_dest) == False:
        shutil.copy2(file_path,file_dest)
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Image Data Generator

# %%
# Definisikan direktori training dan test
TRAIN_DIR = "Dataset-Final/train/"
TEST_DIR = "Dataset-Final/test/"
 
train_normal = os.path.join(TRAIN_DIR + '/NORMAL')
train_pneumonia = os.path.join(TRAIN_DIR + '/PNEUMONIA')
test_normal = os.path.join(TEST_DIR + '/NORMAL')
test_pneumonia = os.path.join(TEST_DIR + '/PNEUMONIA')
 
print("Total number of normal images in training set: ",len(os.listdir(train_normal)))
print("Total number of pneumonic images in training set: ",len(os.listdir(train_pneumonia)))
print("Total number of normal images in test set: ",len(os.listdir(test_normal)))
print("Total number of pneumonic images in test set: ",len(os.listdir(test_pneumonia)))
# Out:
# Total number of normal images in training set:  2850
# Total number of pneumonic images in training set:  3434
# Total number of normal images in test set:  733
# Total number of pneumonic images in test set:  839

# %%
# Buat objek ImageDataGenerator yang menormalkan gambar
datagen = ImageDataGenerator(rescale=1/255.,
                             validation_split = 0.2)
test_datagen = ImageDataGenerator(rescale=1. / 255)
 
train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                              batch_size=32,
                                              target_size=(150,150),
                                              color_mode="grayscale",
                                              class_mode='binary',
                                              subset='training',
                                              shuffle=True)
 
validation_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                   batch_size=32,
                                                   target_size=(150,150),
                                                color_mode="grayscale",
                                                   class_mode='binary',
                                                   subset='validation',
                                                   shuffle=False)
 
test_generator = test_datagen.flow_from_directory(TEST_DIR,
                                                  batch_size=1,
                                                  target_size=(150,150),
                                                  color_mode="grayscale",
                                                  class_mode='binary',
                                                  shuffle=False)
# Out:
# Found 5028 images belonging to 2 classes.
# Found 1256 images belonging to 2 classes.
# Found 1572 images belonging to 2 classes.

# %% [markdown]
# ## Pembangunan Model dengan Beberapa Skema Parameter Tuning

# %%
# tf.keras.backend.clear_session()
 
####################### Init sequential model ##################################
model_1 = Sequential()
 
# ######################### Input layer with Fully Connected Layer ################################
# 1st Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(150,150,1)))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))
 
# 2nd Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (4, 4),padding='same', activation='relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))
 
# 3rd Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (7, 7), padding='same', activation='relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))
 
# Flatten layer
model_1.add(Flatten())
# 1nd Dense Layer
model_1.add(Dense(128, activation = 'relu'))
# 1nd Dropout Layer
model_1.add(Dropout(0.5))
# 2nd Dense Layer
model_1.add(Dense(64, activation = 'relu'))
# 2nd Dropout Layer
model_1.add(Dropout(0.3))
 
# Final Dense layer => For output prediction 1 mean (binary class in dataset), sigmoid for binary cases
model_1.add(Dense(1, activation='sigmoid'))
######################### Fully Connected Layer ################################
 
######################### Compile Model ################################
model_1.compile(optimizer=tf.keras.optimizers.RMSprop(),
                loss='binary_crossentropy',
                metrics=['accuracy'])
 
# Summary of the Model Architecture
print(model_1.summary())
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-17 04:32:42.156032: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 32)     │        16,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 75, 75, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 32)     │        50,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 37, 37, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,327,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,402,881 (5.35 MB)
#  Trainable params: 1,402,689 (5.35 MB)
#  Non-trainable params: 192 (768.00 B)
# None

# %%
count_normal, count_pneumonia = len(os.listdir(train_normal)), len(os.listdir(train_pneumonia))
weight_0 = (1 / count_normal) * (count_normal + count_pneumonia) / 2.0
weight_1 = (1 / count_pneumonia) * (count_pneumonia + count_normal) / 2.0
 
class_weights = {0 : weight_0, 1 : weight_1}
 
# %time
 
# Fitting / training model
history_1 = model_1.fit(train_generator,
                        epochs=30,
                        batch_size=32,
                        validation_data=validation_generator,
                        class_weight = class_weights)
# Out:
# CPU times: user 3 μs, sys: 0 ns, total: 3 μs
# Wall time: 8.34 μs
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 2025-03-17 04:35:51.153511: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 92160000 exceeds 10% of free system memory.
# 2025-03-17 04:35:51.271310: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 92160000 exceeds 10% of free system memory.
# 2025-03-17 04:35:51.316672: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 92160000 exceeds 10% of free system memory.
# 2025-03-17 04:35:51.340856: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 23040000 exceeds 10% of free system memory.
# 2025-03-17 04:35:51.350257: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 23040000 exceeds 10% of free system memory.
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 114s 713ms/step - accuracy: 0.7493 - loss: 1.3346 - val_accuracy: 0.5462 - val_loss: 5.6718
# Epoch 2/30
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 110s 694ms/step - accuracy: 0.9096 - loss: 0.2775 - val_accuracy: 0.5462 - val_loss: 11.4150
# Epoch 3/30
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 121s 763ms/step - accuracy: 0.9401 - loss: 0.2114 - val_accuracy: 0.5486 - val_loss: 5.5188
# Epoch 4/30
# 117/158 ━━━━━━━━━━━━━━━━━━━━ 25s 629ms/step - accuracy: 0.9511 - loss: 0.1723
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 10
#       7 get_ipython().run_line_magic('time', '')
#       9 # Fitting / training model
# ---> 10 history_1 = model_1.fit(train_generator,
#      11                         epochs=30,
#      12                         batch_size=32,
#      13                         validation_data=validation_generator,
#      14                         class_weight = class_weights)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']
loss = history_1.history['loss']
val_loss = history_1.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
 
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('Training and Validaion Loss')
plt.show()

# %%
test_generator.reset()
 
preds_1 = model_1.predict(test_generator,verbose=0)
preds_1 = preds_1.copy()
preds_1[preds_1 <= 0.5] = 0
preds_1[preds_1 > 0.5] = 1
 
# Print Confusion Matrix
cm = pd.DataFrame(data=confusion_matrix(test_generator.classes, preds_1, labels=[0, 1]),index=["Actual Normal", "Actual Pneumonia"],
columns=["Predicted Normal", "Predicted Pneumonia"])
sns.heatmap(cm,annot=True,fmt="d")
 
# Print Classification Report
print("\n")
print(classification_report(y_true=test_generator.classes,y_pred=preds_1,target_names =['Normal','Pneumonia'], digits=4))
